# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

# %%
#only for representation purpose, viewing the data as pandas dataframe
data=fetch_california_housing(as_frame=True) #function from scikit-learn to load california housing dataset (as_frame=True --> to view in pandas Dataframe)
X=data.data                                  #extracting features(input variables) from dataset
y=data.target                                #extracting target(output variables)
X
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
housing=fetch_california_housing(as_frame=False)  # notice how we are not using pandas here
X=housing.data
y=housing.target
X
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#           39.37      , -121.24      ]])

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing(as_frame=False) # loading dataset(numpy array)
X = housing.data
y = housing.target

medinc_index = housing.feature_names.index("MedInc") #Finding column index of MedInc

# Visualize the strongest relationship: Median Income vs House Value
plt.figure(figsize=(6,6))
# Use the integer index for the MedInc column
plt.scatter(X[:, medinc_index], y, alpha=0.3)
plt.xlabel("Median Income (in $10,000s)")
plt.ylabel("Median House Value ($100,000s)")
plt.title("Median Income vs House Value")
plt.yticks([0, 2, 4, 6])
plt.show()

# %%
#normalising the input data, X
def minmax(X):
    X_scaled = np.zeros_like(X)
    for i in range(X.shape[1]):
        X_scaled[:, i]=(X[:, i]-np.min(X[:, i]))/(np.max(X[:, i])-np.min(X[:, i]))
    return X_scaled

# %%
X_scaled=minmax(X)
X_scaled
# Out:
# array([[0.53966842, 0.78431373, 0.0435123 , ..., 0.00149943, 0.5674814 ,
#         0.21115538],
#        [0.53802706, 0.39215686, 0.03822395, ..., 0.00114074, 0.565356  ,
#         0.21215139],
#        [0.46602805, 1.        , 0.05275646, ..., 0.00169796, 0.5642933 ,
#         0.21015936],
#        ...,
#        [0.08276438, 0.31372549, 0.03090386, ..., 0.0013144 , 0.73219979,
#         0.31175299],
#        [0.09429525, 0.33333333, 0.03178269, ..., 0.0011515 , 0.73219979,
#         0.30179283],
#        [0.13025338, 0.29411765, 0.03125246, ..., 0.00154886, 0.72582359,
#         0.30976096]])

# %%
X_train, X_test, y_train, y_test=train_test_split(X_scaled, y, test_size=0.2, random_state=10)
X_train.shape, y_train.shape
# Out:
# ((16512, 8), (16512,))

# %%
def initialise():
    np.random.seed(10)
    w=np.random.rand(X.shape[1])
    b=np.random.rand()

    return w, b

# %%
def mse(y, y_pred):
    return np.mean((y-y_pred)**2)

# %%
def prediction(x,w,b):
    return np.dot(x,w)+b

# %%
def train_model(X, y, epochs, alpha, n,w, b):
    for i in range(epochs):
        y_pred=prediction(X,w, b)
        dw=(-2/n)*np.dot(X.T, (y-y_pred))
        db=(-2/n)*np.sum((y-y_pred))
        w=w-alpha*dw
        b=b-alpha*db

        if(i%100==0):
            print("loss=", mse(y, y_pred))
    return w, b

# %%
epochs=30000
alpha=0.1
n=X_train.shape[0]
w,b=initialise()
w, b=train_model(X_train, y_train, epochs, alpha, n,w, b)
w, b
# Out:
# loss= 2.704489927032725
# loss= 0.9131116601741776
# loss= 0.767893386884225
# loss= 0.6903189034928572
# loss= 0.6476676513828461
# loss= 0.6231609157186785
# loss= 0.6081709778846125
# loss= 0.5982534140720359
# loss= 0.5911121484810491
# loss= 0.585554988154714
# loss= 0.5809574331052832
# loss= 0.5769873713732276
# loss= 0.5734636887243116
# loss= 0.5702836214526736
# loss= 0.5673854001002162
# loss= 0.564729012988883
# loss= 0.5622862753924853
# loss= 0.5600356797319767
# loss= 0.5579597039943406
# loss= 0.5560433857734915
# loss= 0.554273549477123
# loss= 0.5526383720505035
# loss= 0.5511271254519572
# loss= 0.5497300126090443
# loss= 0.5484380538937753
# loss= 0.5472430018630289
# loss= 0.5461372726555727
# loss= 0.5451138879159808
# loss= 0.5441664239416351
# loss= 0.5432889662120561
# loss= 0.5424760682223246
# loss= 0.5417227139443724
# loss= 0.5410242834560668
# loss= 0.5403765213979415
# loss= 0.5397755079872856
# loss= 0.5392176323627811
# loss= 0.5386995680622022
# loss= 0.5382182504572182
# loss= 0.537770855986319
# loss= 0.537354783041074
# loss= 0.5369676343732493
# loss= 0.5366072009012712
# loss= 0.5362714468043971
# loss= 0.5359584958019666
# loss= 0.5356666185233279
# loss= 0.5353942208815845
# loss= 0.5351398333712415
# loss= 0.5349021012162014
# loss= 0.5346797753004258
# loss= 0.5344717038189672
# loss= 0.5342768245920427
# loss= 0.534094157989386
# loss= 0.5339228004163143
# loss= 0.5337619183168211
# loss= 0.5336107426525549
# loss= 0.5334685638198332
# loss= 0.5333347269698409
# loss= 0.5332086276999505
# loss= 0.5330897080866457
# loss= 0.5329774530328838
# loss= 0.5328713869048962
# loss= 0.532771070435415
# loss= 0.5326760978721441
# loss= 0.5325860943519849
# loss= 0.5325007134830744
# loss= 0.5324196351181181
# loss= 0.5323425633038256
# loss= 0.5322692243924535
# loss= 0.5321993653025829
# loss= 0.5321327519172808
# loss= 0.5320691676087329
# loss= 0.5320084118793144
# loss= 0.5319502991098506
# loss= 0.5318946574065655
# loss= 0.5318413275388874
# loss= 0.5317901619609051
# loss= 0.5317410239098405
# loss= 0.5316937865754323
# loss= 0.5316483323346103
# loss= 0.5316045520462866
# loss= 0.531562344401501
# loss= 0.5315216153245379
# loss= 0.5314822774209784
# loss= 0.5314442494689738
# loss= 0.5314074559503206
# loss= 0.5313718266181889
# loss= 0.5313372960986081
# loss= 0.5313038035230405
# loss= 0.5312712921895875
# loss= 0.5312397092505677
# loss= 0.5312090054243885
# loss= 0.5311791347297881
# loss= 0.5311500542406914
# loss= 0.5311217238600512
# loss= 0.5310941061111817
# loss= 0.5310671659452042
# loss= 0.5310408705633427
# loss= 0.531015189252897
# loss= 0.5309900932358225
# loss= 0.5309655555289239
# loss= 0.5309415508147559
# loss= 0.5309180553223869
# loss= 0.5308950467172566
# loss= 0.5308725039994159
# loss= 0.5308504074094904
# loss= 0.5308287383417687
# loss= 0.5308074792638572
# loss= 0.5307866136423888
# loss= 0.5307661258743165
# loss= 0.5307460012233552
# loss= 0.5307262257611738
# loss= 0.5307067863129673
# loss= 0.5306876704070707
# loss= 0.5306688662283022
# loss= 0.5306503625747455
# loss= 0.5306321488177093
# loss= 0.5306142148646157
# loss= 0.5305965511245949
# loss= 0.5305791484765772
# loss= 0.5305619982396916
# loss= 0.530545092145794
# loss= 0.5305284223139625
# loss= 0.5305119812268104
# loss= 0.5304957617084796
# loss= 0.5304797569041836
# loss= 0.5304639602611882
# loss= 0.5304483655111157
# loss= 0.5304329666534773
# loss= 0.5304177579403403
# loss= 0.5304027338620431
# loss= 0.5303878891338839
# loss= 0.5303732186837058
# loss= 0.5303587176403166
# loss= 0.5303443813226778
# loss= 0.5303302052298083
# loss= 0.5303161850313505
# loss= 0.5303023165587485
# loss= 0.5302885957969948
# loss= 0.5302750188769068
# loss= 0.5302615820678895
# loss= 0.5302482817711553
# loss= 0.5302351145133629
# loss= 0.5302220769406502
# loss= 0.5302091658130292
# loss= 0.530196377999122
# loss= 0.5301837104712072
# loss= 0.5301711603005633
# loss= 0.5301587246530823
# loss= 0.5301464007851365
# loss= 0.5301341860396838
# loss= 0.5301220778425909
# loss= 0.5301100736991631
# loss= 0.5300981711908662
# loss= 0.5300863679722264
# loss= 0.5300746617678963
# loss= 0.5300630503698802
# loss= 0.5300515316349016
# loss= 0.5300401034819097
# loss= 0.5300287638897128
# loss= 0.5300175108947317
# loss= 0.5300063425888648
# loss= 0.5299952571174583
# loss= 0.5299842526773763
# loss= 0.5299733275151615
# loss= 0.5299624799252848
# loss= 0.5299517082484763
# loss= 0.5299410108701317
# loss= 0.5299303862187934
# loss= 0.529919832764698
# loss= 0.5299093490183897
# loss= 0.5298989335293925
# loss= 0.5298885848849413
# loss= 0.5298783017087666
# loss= 0.5298680826599285
# loss= 0.5298579264317028
# loss= 0.5298478317505088
# loss= 0.5298377973748828
# loss= 0.5298278220944913
# loss= 0.5298179047291853
# loss= 0.5298080441280878
# loss= 0.5297982391687196
# loss= 0.5297884887561577
# loss= 0.5297787918222234
# loss= 0.5297691473247034
# loss= 0.5297595542465967
# loss= 0.5297500115953918
# loss= 0.529740518402367
# loss= 0.5297310737219175
# loss= 0.5297216766309049
# loss= 0.5297123262280304
# loss= 0.5297030216332295
# loss= 0.5296937619870855
# loss= 0.5296845464502656
# loss= 0.5296753742029737
# loss= 0.5296662444444223
# loss= 0.5296571563923218
# loss= 0.5296481092823851
# loss= 0.5296391023678502
# loss= 0.5296301349190166
# loss= 0.5296212062227968
# loss= 0.5296123155822822
# loss= 0.5296034623163213
# loss= 0.5295946457591132
# loss= 0.5295858652598116
# loss= 0.5295771201821409
# loss= 0.5295684099040256
# loss= 0.5295597338172293
# loss= 0.5295510913270046
# loss= 0.5295424818517545
# loss= 0.5295339048227019
# loss= 0.5295253596835708
# loss= 0.5295168458902751
# loss= 0.5295083629106176
# loss= 0.5294999102239965
# loss= 0.5294914873211208
# loss= 0.5294830937037353
# loss= 0.5294747288843497
# loss= 0.529466392385979
# loss= 0.5294580837418894
# loss= 0.5294498024953508
# loss= 0.5294415481993976
# loss= 0.5294333204165946
# loss= 0.5294251187188109
# loss= 0.5294169426869979
# loss= 0.529408791910975
# loss= 0.529400665989221
# loss= 0.5293925645286688
# loss= 0.5293844871445098
# loss= 0.5293764334599995
# loss= 0.5293684031062698
# loss= 0.5293603957221468
# loss= 0.5293524109539723
# loss= 0.5293444484554317
# loss= 0.5293365078873831
# loss= 0.5293285889176945
# loss= 0.5293206912210829
# loss= 0.5293128144789592
# loss= 0.5293049583792737
# loss= 0.5292971226163711
# loss= 0.5292893068908433
# loss= 0.5292815109093908
# loss= 0.5292737343846831
# loss= 0.5292659770352274
# loss= 0.5292582385852361
# loss= 0.5292505187645009
# loss= 0.529242817308268
# loss= 0.5292351339571181
# loss= 0.529227468456847
# loss= 0.5292198205583515
# loss= 0.5292121900175175
# loss= 0.5292045765951093
# loss= 0.5291969800566638
# loss= 0.5291894001723861
# loss= 0.529181836717047
# loss= 0.5291742894698845
# loss= 0.5291667582145069
# loss= 0.5291592427387981
# loss= 0.5291517428348252
# loss= 0.5291442582987486
# loss= 0.5291367889307335
# loss= 0.529129334534865
# loss= 0.5291218949190636
# loss= 0.5291144698950029
# loss= 0.5291070592780314
# loss= 0.5290996628870921
# loss= 0.529092280544648
# loss= 0.5290849120766068
# loss= 0.5290775573122486
# loss= 0.5290702160841543
# loss= 0.5290628882281366
# loss= 0.5290555735831722
# loss= 0.5290482719913355
# loss= 0.5290409832977333
# loss= 0.5290337073504424
# loss= 0.529026444000447
# loss= 0.529019193101579
# loss= 0.5290119545104581
# loss= 0.5290047280864352
# loss= 0.5289975136915345
# loss= 0.5289903111903997
# loss= 0.5289831204502395
# loss= 0.5289759413407749
# loss= 0.5289687737341875
# loss= 0.5289616175050695
# loss= 0.5289544725303742
# loss= 0.5289473386893676
# loss= 0.5289402158635818
# loss= 0.5289331039367687
# loss= 0.5289260027948545
# loss= 0.5289189123258967
# loss= 0.5289118324200396
# loss= 0.5289047629694728
# loss= 0.5288977038683907
# loss= 0.528890655012951
# loss= 0.5288836163012351
# loss= 0.5288765876332109
# loss= 0.5288695689106933
# loss= 0.5288625600373087
# loss= 0.5288555609184578
# loss= 0.5288485714612804
# (array([ 5.46913884,  0.4804926 ,  0.34884997,  3.77282108, -0.11232482,
#         -0.74500848, -4.37797717, -4.7481613 ]),
#  np.float64(4.144428494749769))

# %%
print(np.column_stack((prediction(X_test, w, b), y_test)))
# Out:
# [[2.92977979 1.674     ]
#  [2.49126405 3.541     ]
#  [2.20971941 1.602     ]
#  ...
#  [2.34992653 1.313     ]
#  [1.27553674 0.923     ]
#  [3.68163813 5.00001   ]]

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# train the model
model = LinearRegression()
model.fit(X_train, y_train)

# predict on test set
y_pred_sklearn = model.predict(X_test)

# view both arrays side by side
print(np.column_stack((y_pred_sklearn[:10], y_test[:10])))
# Out:
# [[3.00511808 1.674     ]
#  [2.56692165 3.541     ]
#  [2.33800105 1.602     ]
#  [1.71407997 1.408     ]
#  [1.76334162 1.078     ]
#  [0.77485129 1.188     ]
#  [2.18514506 1.549     ]
#  [2.24346327 2.081     ]
#  [1.15700777 0.923     ]
#  [3.39072454 4.04      ]]

# %%
y_pred = prediction(X_test, w, b).flatten()
y_test_flat = y_test.flatten()

plt.figure(figsize=(8, 8))
plt.scatter(y_test_flat, y_pred, alpha=0.6, s=50)

# Perfect prediction line (45 degree)
min_val = min(y_test_flat.min(), y_pred.min())
max_val = max(y_test_flat.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2, label='Perfect Prediction')

plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted (All Features)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.axis('equal')
plt.show()

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Create a mesh for the regression plane
x0_range = np.linspace(X_test[:, 0].min(), X_test[:, 0].max(), 20)
x1_range = np.linspace(X_test[:, 1].min(), X_test[:, 1].max(), 20)
x0_mesh, x1_mesh = np.meshgrid(x0_range, x1_range)

# Create synthetic X with other features at their mean
X_synthetic = np.tile(X_test.mean(axis=0), (x0_mesh.size, 1))
X_synthetic[:, 0] = x0_mesh.flatten()
X_synthetic[:, 1] = x1_mesh.flatten()

# Get predictions for the mesh
z_mesh = prediction(X_synthetic, w, b).reshape(x0_mesh.shape)

# Plot the surface
surf = ax.plot_surface(x0_mesh, x1_mesh, z_mesh, alpha=0.3, cmap='viridis')

# Plot actual points
ax.scatter(X_test[:, 0], X_test[:, 1], y_test_flat,
           c='blue', label='Actual', s=50, alpha=0.8)

ax.set_xlabel('Feature 0')
ax.set_ylabel('Feature 1')
ax.set_zlabel('Target Value')
ax.set_title('Regression Surface with Actual Data Points')
ax.legend()
plt.colorbar(surf, shrink=0.5)
plt.show()
